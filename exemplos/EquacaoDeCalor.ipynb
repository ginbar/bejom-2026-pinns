# %% [markdown]
# # Equação de Calor
# ----

# %% [markdown]
# ## Bibliotecas
#
# Utilizaremos o DeepXDE junto com PyTorch para resolver estas equações.

# %%
import os
os.environ['DDE_BACKEND'] = 'pytorch'
import deepxde as dde
import numpy as np
import pandas as pd
import scipy
from matplotlib import pyplot as plt
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.

# %%
# https://deepxde.readthedocs.io/en/latest/modules/deepxde.optimizers.html#module-deepxde.optimizers.config
dde.config.set_default_float("float64")

# Para reprodução dos experimentos
np.random.seed(42)
dde.config.set_random_seed(42)
# Out:
# Set the default float type to float64

# %% [markdown]
# ## Modelo equação de calor
#
# $$
# \frac{\partial u}{\partial t}(x,t) - \alpha \frac{\partial^2 u}{\partial x^2}(x,t) = f(x,t), \quad x \in (0,\ell), \ t> 0
# $$

# %%
a = 1

# %%
def pde(x, y):
    dy_dt = dde.grad.jacobian(y, x, i=0, j=1)
    dy_dxx = dde.grad.hessian(y, x, i=0, j=0)
    return dy_dt - a * dy_dxx

# %% [markdown]
# ## Limites
#
# $$
# x \in (0,\ell), \ t> 0
# $$

# %%
L = 1
n = 1

# %%
t0, tf = 0, 1

geom = dde.geometry.Interval(0, L)
timedomain = dde.geometry.TimeDomain(t0, tf)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

# %% [markdown]
# ## Condições de contorno e iniciais

# %%
bc = dde.icbc.DirichletBC(geomtime, lambda x: 0, lambda _, on_boundary: on_boundary)

ic = dde.icbc.IC(
    geomtime,
    lambda x: np.sin(n * np.pi * x[:, 0:1] / L),
    lambda _, on_initial: on_initial,
)

# %% [markdown]
# ## Solução Exata
#
# $$
# u(x,t) = e^{\frac{-\alpha \pi^2 t}{\ell}} \sin \Big( \frac{\pi x}{\ell} \Big)
# $$

# %%
def exact_solution(X):
    x, t = X[:,0], X[:,1]
    return np.exp(-(n**2 * np.pi**2 * a * t) / (L**2)) * np.sin(n * np.pi * x / L)

# %% [markdown]
# ## Dados de treinamento

# %%
data = dde.data.TimePDE(
    geomtime,
    pde,
    [bc, ic],
    num_domain=2500,
    num_boundary=80,
    num_initial=160,
    num_test=150
)
# Out:
# Warning: 150 points required, but 156 points sampled.

# %% [markdown]
# ## Otimizando a rede

# %%
n_hidden_layers = [1, 2, 3, 4, 5, 6]
n_nodes_per_layer = [10, 20, 40]

# n_hidden_layers = [1]
# n_nodes_per_layer = [10]

# %%
def create_test_points(nop):
    
    x = np.linspace(0, L, nop)
    t = np.linspace(t0, tf, nop)
    
    X, T = np.meshgrid(x, t)
    XT = np.vstack((X.flatten(), T.flatten())).T

    return X, T, XT

# %%
nop = 50
_, _, test_points = create_test_points(nop)

table = []

for n_hidden_l in n_hidden_layers:
    for n_nodes in n_nodes_per_layer:
        
        net = dde.nn.FNN([2] + [n_nodes] * n_hidden_l + [1], "tanh", "Glorot normal")
        model = dde.Model(data, net)
        
        model.compile("adam", lr=1e-3)
    
        losshistory, train_state = model.train(
            iterations=20000, 
            model_save_path=f"../modelos/heat_{n_nodes}x{n_hidden_l}")

        exact = exact_solution(test_points).reshape((nop, nop))
        pinns = model.predict(test_points).reshape((nop, nop))

        print(scipy.linalg.norm(exact - pinns, ord=np.inf))
        print(np.max(np.abs(pinns - exact)))
        
        #l_infinity = scipy.linalg.norm(exact - pinns, ord=np.inf)
        l_infinity = np.max(np.abs(pinns - exact))
        
        table.append([n_hidden_l, n_nodes, l_infinity])
# Out:
# Compiling model...
# 'compile' took 1.892664 s
#
# Training model...
# /home/gabriel/anaconda3/envs/ermac_2025/lib/python3.12/site-packages/torch/autograd/graph.py:825: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /opt/conda/conda-bld/pytorch_1729647378361/work/aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Step      Train loss                        Test loss                         Test metric
# 0         [6.29e-02, 9.84e-01, 2.82e+00]    [4.84e-02, 9.84e-01, 2.82e+00]    []
# 1000      [1.57e-02, 5.06e-02, 1.12e-01]    [1.19e-02, 5.06e-02, 1.12e-01]    []
# 2000      [1.68e-02, 4.73e-02, 9.53e-02]    [1.27e-02, 4.73e-02, 9.53e-02]    []
# 3000      [9.35e-03, 4.61e-02, 8.82e-02]    [6.58e-03, 4.61e-02, 8.82e-02]    []
# 4000      [1.01e-02, 3.56e-02, 7.38e-02]    [6.63e-03, 3.56e-02, 7.38e-02]    []
# 5000      [1.04e-02, 2.70e-02, 6.58e-02]    [6.36e-03, 2.70e-02, 6.58e-02]    []
# 6000      [1.39e-02, 1.74e-02, 5.44e-02]    [8.11e-03, 1.74e-02, 5.44e-02]    []
# 7000      [1.21e-02, 1.38e-02, 4.73e-02]    [6.51e-03, 1.38e-02, 4.73e-02]    []
# 8000      [1.07e-02, 1.19e-02, 3.96e-02]    [6.48e-03, 1.19e-02, 3.96e-02]    []
# 9000      [1.03e-02, 6.63e-03, 2.74e-02]    [6.05e-03, 6.63e-03, 2.74e-02]    []
# 10000     [9.29e-03, 5.38e-03, 2.09e-02]    [5.09e-03, 5.38e-03, 2.09e-02]    []
# 11000     [1.02e-02, 3.63e-03, 1.74e-02]    [6.33e-03, 3.63e-03, 1.74e-02]    []
# 12000     [8.14e-03, 2.14e-03, 1.14e-02]    [5.65e-03, 2.14e-03, 1.14e-02]    []
# 13000     [7.60e-03, 1.85e-03, 9.88e-03]    [5.30e-03, 1.85e-03, 9.88e-03]    []
# 14000     [7.15e-03, 1.75e-03, 8.85e-03]    [5.14e-03, 1.75e-03, 8.85e-03]    []
# 15000     [6.82e-03, 1.66e-03, 8.03e-03]    [5.05e-03, 1.66e-03, 8.03e-03]    []
# 16000     [6.59e-03, 1.60e-03, 7.45e-03]    [4.96e-03, 1.60e-03, 7.45e-03]    []
# 17000     [6.37e-03, 1.64e-03, 6.98e-03]    [4.92e-03, 1.64e-03, 6.98e-03]    []
# 18000     [6.18e-03, 1.69e-03, 6.61e-03]    [4.88e-03, 1.69e-03, 6.61e-03]    []
# 19000     [5.98e-03, 1.66e-03, 6.36e-03]    [4.69e-03, 1.66e-03, 6.36e-03]    []
# 20000     [5.75e-03, 1.70e-03, 6.06e-03]    [4.56e-03, 1.70e-03, 6.06e-03]    []
#
# Best model at step 20000:
#   train loss: 1.35e-02
#   test loss: 1.23e-02
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat
s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [1.49e-02, 4.73e-02, 3.32e-01]    [1.50e-02, 4.73e-02, 3.32e-01]    []
# 1000      [4.43e-03, 3.79e-02, 7.14e-02]    [2.89e-03, 3.79e-02, 7.14e-02]    []
# 2000      [6.39e-03, 7.85e-03, 2.69e-02]    [3.57e-03, 7.85e-03, 2.69e-02]    []
# 3000      [5.50e-03, 3.89e-03, 1.36e-02]    [3.27e-03, 3.89e-03, 1.36e-02]    []
# 4000      [3.53e-03, 1.96e-03, 7.30e-03]    [1.68e-03, 1.96e-03, 7.30e-03]    []
# 5000      [3.51e-03, 9.23e-04, 3.79e-03]    [2.24e-03, 9.23e-04, 3.79e-03]    []
# 6000      [3.24e-03, 6.49e-04, 2.66e-03]    [2.22e-03, 6.49e-04, 2.66e-03]    []
# 7000      [2.51e-03, 5.44e-04, 1.97e-03]    [1.63e-03, 5.44e-04, 1.97e-03]    []
# 8000      [2.03e-03, 4.52e-04, 1.38e-03]    [1.35e-03, 4.52e-04, 1.38e-03]    []
# 9000      [2.00e-03, 3.91e-04, 1.02e-03]    [1.50e-03, 3.91e-04, 1.02e-03]    []
# 10000     [2.02e-03, 3.42e-04, 8.67e-04]    [1.61e-03, 3.42e-04, 8.67e-04]    []
# 11000     [1.97e-03, 3.17e-04, 7.86e-04]    [1.60e-03, 3.17e-04, 7.86e-04]    []
# 12000     [1.93e-03, 2.96e-04, 7.34e-04]    [1.58e-03, 2.96e-04, 7.34e-04]    []
# 13000     [1.92e-03, 2.99e-04, 6.76e-04]    [1.57e-03, 2.99e-04, 6.76e-04]    []
# 14000     [1.85e-03, 2.65e-04, 6.59e-04]    [1.50e-03, 2.65e-04, 6.59e-04]    []
# 15000     [1.80e-03, 2.54e-04, 6.27e-04]    [1.45e-03, 2.54e-04, 6.27e-04]    []
# 16000     [1.76e-03, 2.42e-04, 5.99e-04]    [1.41e-03, 2.42e-04, 5.99e-04]    []
# 17000     [1.76e-03, 2.30e-04, 5.74e-04]    [1.39e-03, 2.30e-04, 5.74e-04]    []
# 18000     [1.68e-03, 2.24e-04, 5.46e-04]    [1.31e-03, 2.24e-04, 5.46e-04]    []
# 19000     [1.63e-03, 2.18e-04, 5.20e-04]    [1.27e-03, 2.18e-04, 5.20e-04]    []
# 20000     [1.59e-03, 2.11e-04, 4.95e-04]    [1.22e-03, 2.11e-04, 4.95e-04]    []
#
# Best model at step 20000:
#   train loss: 2.29e-03
#   test loss: 1.92e-03
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_40x1-20000.pt ...
#
# 'train' took 77.440824 s
#
# 1.0983975109762294
# 0.041556075100922144
# Compiling model...
# 'compile' took 0.000097 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [2.13e-01, 1.20e-01, 3.91e-01]    [2.00e-01, 1.20e-01, 3.91e-01]    []
# 1000      [6.96e-03, 3.14e-02, 6.27e-02]    [3.80e-03, 3.14e-02, 6.27e-02]    []
# 2000      [4.30e-03, 2.81e-03, 8.29e-03]    [2.45e-03, 2.81e-03, 8.29e-03]    []
# 3000      [1.47e-03, 3.92e-04, 6.04e-04]    [5.67e-04, 3.92e-04, 6.04e-04]    []
# 4000      [9.85e-04, 1.38e-04, 1.59e-04]    [4.42e-04, 1.38e-04, 1.59e-04]    []
# 5000      [6.70e-04, 1.05e-04, 7.79e-05]    [3.23e-04, 1.05e-04, 7.79e-05]    []
# 6000      [4.73e-04, 9.42e-05, 4.73e-05]    [2.53e-04, 9.42e-05, 4.73e-05]    []
# 7000      [3.61e-04, 8.06e-05, 3.27e-05]    [2.04e-04, 8.06e-05, 3.27e-05]    []
# 13000     [1.44e-04, 1.80e-05, 2.20e-05]    [1.02e-04, 1.80e-05, 2.20e-05]    []
# 14000     [1.34e-04, 1.64e-05, 1.92e-05]    [9.45e-05, 1.64e-05, 1.92e-05]    []
# 15000     [1.71e-04, 1.69e-05, 1.58e-05]    [1.15e-04, 1.69e-05, 1.58e-05]    []
# 16000     [1.16e-04, 1.39e-05, 1.47e-05]    [8.08e-05, 1.39e-05, 1.47e-05]    []
# 17000     [1.08e-04, 1.27e-05, 1.29e-05]    [7.36e-05, 1.27e-05, 1.29e-05]    []
# 18000     [1.01e-04, 1.16e-05, 1.13e-05]    [6.76e-05, 1.16e-05, 1.13e-05]    []
# 19000     [9.81e-05, 1.08e-05, 1.05e-05]    [6.15e-05, 1.08e-05, 1.05e-05]    []
# 20000     [8.91e-05, 1.00e-05, 8.98e-06]    [5.63e-05, 1.00e-05, 8.98e-06]    []
#
# Best model at step 20000:
#   train loss: 1.08e-04
#   test loss: 7.53e-05
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_20x2-20000.pt ...
#
# 'train' took 101.955659 s
#
# 0.18753182196744056
# 0.007599182822908041
# Compiling model...
# 'compile' took 0.000098 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [8.63e-03, 4.14e-03, 5.29e-01]    [8.86e-03, 4.14e-03, 5.29e-01]    []
# 1000      [4.16e-03, 1.55e-03, 7.08e-03]    [2.03e-03, 1.55e-03, 7.08e-03]    []
# 2000      [1.19e-03, 2.10e-04, 7.52e-04]    [7.96e-04, 2.10e-04, 7.52e-04]    []
# 3000      [5.99e-04, 1.19e-04, 2.68e-04]    [4.34e-04, 1.19e-04, 2.68e-04]    []
# 4000      [3.56e-04, 7.08e-05, 1.24e-04]    [2.61e-04, 7.08e-05, 1.24e-04]    []
# 5000      [2.11e-04, 3.79e-05, 6.06e-05]    [1.39e-04, 3.79e-05, 6.06e-05]    []
# 6000      [2.07e-04, 2.57e-05, 3.50e-05]    [1.21e-04, 2.57e-05, 3.50e-05]    []
# 7000      [1.00e-04, 1.07e-05, 1.79e-05]    [5.91e-05, 1.07e-05, 1.79e-05]    []
# 8000      [8.00e-05, 6.29e-06, 1.12e-05]    [4.83e-05, 6.29e-06, 1.12e-05]    []
# 9000      [3.04e-04, 2.68e-05, 9.47e-06]    [1.88e-04, 2.68e-05, 9.47e-06]    []
# 10000     [6.15e-05, 3.02e-06, 5.73e-06]    [3.91e-05, 3.02e-06, 5.73e-06]    []
# 11000     [6.52e-05, 3.18e-06, 4.54e-06]    [4.39e-05, 3.18e-06, 4.54e-06]    []
# 12000     [5.29e-05, 2.10e-06, 3.79e-06]    [3.45e-05, 2.10e-06, 3.79e-06]    []
# 13000     [5.85e-05, 2.60e-06, 3.61e-06]    [3.80e-05, 2.60e-06, 3.61e-06]    []
# 14000     [4.57e-05, 1.52e-06, 2.86e-06]    [3.10e-05, 1.52e-06, 2.86e-06]    []
# 15000     [4.32e-05, 1.35e-06, 2.52e-06]    [2.95e-05, 1.35e-06, 2.52e-06]    []
# 16000     [4.34e-05, 1.43e-06, 2.35e-06]    [3.04e-05, 1.43e-06, 2.35e-06]    []
# 17000     [6.33e-05, 3.39e-06, 2.15e-06]    [4.34e-05, 3.39e-06, 2.15e-06]    []
# 18000     [3.72e-05, 1.09e-06, 2.02e-06]    [2.55e-05, 1.09e-06, 2.02e-06]    []
# 19000     [4.43e-05, 1.84e-06, 1.99e-06]    [3.04e-05, 1.84e-06, 1.99e-06]    []
# 20000     [5.31e-05, 2.39e-06, 1.86e-06]    [3.84e-05, 2.39e-06, 1.86e-06]    []
#
# Best model at step 18000:
#   train loss: 4.03e-05
#   test loss: 2.86e-05
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_40x2-20000.pt ...
#
# 'train' took 169.616191 s
#
# 0.09735831790876613
# 0.0038378561557953815
# Compiling model...
# 'compile' took 0.000096 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [1.12e-01, 2.26e-02, 4.25e-01]    [9.50e-02, 2.26e-02, 4.25e-01]    []
# 1000      [8.85e-03, 7.78e-03, 2.63e-02]    [4.01e-03, 7.78e-03, 2.63e-02]    []
# 2000      [3.22e-03, 1.13e-03, 3.01e-03]    [1.74e-03, 1.13e-03, 3.01e-03]    []
# 3000      [1.04e-03, 3.04e-04, 5.18e-04]    [3.85e-04, 3.04e-04, 5.18e-04]    []
# 4000      [2.51e-03, 1.64e-04, 4.00e-04]    [9.60e-04, 1.64e-04, 4.00e-04]    []
# 5000      [3.50e-04, 8.98e-05, 6.13e-05]    [8.62e-05, 8.98e-05, 6.13e-05]    []
# 6000      [2.58e-04, 6.18e-05, 3.11e-05]    [7.31e-05, 6.18e-05, 3.11e-05]    []
# 7000      [2.03e-04, 4.23e-05, 1.56e-05]    [6.31e-05, 4.23e-05, 1.56e-05]    []
# 8000      [1.67e-04, 3.07e-05, 8.33e-06]    [5.41e-05, 3.07e-05, 8.33e-06]    []
# 9000      [1.41e-04, 2.33e-05, 4.60e-06]    [4.76e-05, 2.33e-05, 4.60e-06]    []
# 10000     [1.44e-03, 2.07e-05, 1.71e-04]    [4.37e-04, 2.07e-05, 1.71e-04]    []
# 11000     [1.16e-04, 1.62e-05, 7.43e-06]    [4.47e-05, 1.62e-05, 7.43e-06]    []
# 12000     [9.84e-05, 1.28e-05, 1.37e-06]    [3.79e-05, 1.28e-05, 1.37e-06]    []
# 13000     [8.95e-05, 1.08e-05, 8.16e-07]    [3.60e-05, 1.08e-05, 8.16e-07]    []
# 14000     [8.19e-05, 9.22e-06, 5.48e-07]    [3.43e-05, 9.22e-06, 5.48e-07]    []
# 15000     [7.51e-05, 8.01e-06, 3.96e-07]    [3.27e-05, 8.01e-06, 3.96e-07]    []
# 16000     [6.99e-05, 7.45e-06, 9.21e-07]    [3.24e-05, 7.45e-06, 9.21e-07]    []
# 17000     [6.39e-05, 6.29e-06, 3.19e-07]    [3.01e-05, 6.29e-06, 3.19e-07]    []
# 18000     [5.97e-05, 5.56e-06, 2.41e-07]    [2.89e-05, 5.56e-06, 2.41e-07]    []
# 19000     [5.69e-05, 5.04e-06, 3.15e-07]    [2.86e-05, 5.04e-06, 3.15e-07]    []
# 20000     [5.33e-05, 4.48e-06, 2.72e-07]    [2.71e-05, 4.48e-06, 2.72e-07]    []
#
# Best model at step 20000:
#   train loss: 5.81e-05
#   test loss: 3.19e-05
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_10x3-20000.pt ...
#
# 'train' took 85.806369 s
#
# 0.11422221352829337
# 0.00490804123537918
# Compiling model...
# 'compile' took 0.000091 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [6.81e-02, 6.39e-03, 5.37e-01]    [5.93e-02, 6.39e-03, 5.37e-01]    []
# 1000      [4.17e-03, 1.76e-03, 6.10e-03]    [2.27e-03, 1.76e-03, 6.10e-03]    []
# 2000      [9.54e-04, 4.54e-04, 6.58e-04]    [5.61e-04, 4.54e-04, 6.58e-04]    []
# 3000      [5.58e-04, 1.46e-04, 2.56e-04]    [3.01e-04, 1.46e-04, 2.56e-04]    []
# 4000      [3.16e-04, 5.66e-05, 1.17e-04]    [1.53e-04, 5.66e-05, 1.17e-04]    []
# 5000      [2.05e-04, 3.00e-05, 6.11e-05]    [8.91e-05, 3.00e-05, 6.11e-05]    []
# 6000      [1.54e-04, 2.06e-05, 3.97e-05]    [6.34e-05, 2.06e-05, 3.97e-05]    []
# 7000      [1.65e-04, 1.59e-05, 2.93e-05]    [6.78e-05, 1.59e-05, 2.93e-05]    []
# 8000      [1.05e-04, 1.25e-05, 2.26e-05]    [4.01e-05, 1.25e-05, 2.26e-05]    []
# 9000      [9.23e-05, 1.04e-05, 1.83e-05]    [3.39e-05, 1.04e-05, 1.83e-05]    []
# 10000     [8.18e-05, 8.79e-06, 1.53e-05]    [2.92e-05, 8.79e-06, 1.53e-05]    []
# 11000     [7.37e-05, 7.58e-06, 1.30e-05]    [2.55e-05, 7.58e-06, 1.30e-05]    []
# 12000     [6.72e-05, 6.60e-06, 1.12e-05]    [2.26e-05, 6.60e-06, 1.12e-05]    []
# 13000     [6.14e-05, 5.82e-06, 9.75e-06]    [2.02e-05, 5.82e-06, 9.75e-06]    []
# 14000     [5.67e-05, 5.17e-06, 8.46e-06]    [1.85e-05, 5.17e-06, 8.46e-06]    []
# 15000     [5.01e-04, 2.68e-05, 1.09e-05]    [2.10e-04, 2.68e-05, 1.09e-05]    []
# 16000     [4.89e-05, 4.14e-06, 6.53e-06]    [1.57e-05, 4.14e-06, 6.53e-06]    []
# 17000     [6.18e-05, 5.93e-06, 1.24e-05]    [2.68e-05, 5.93e-06, 1.24e-05]    []
# 18000     [4.28e-05, 3.46e-06, 5.13e-06]    [1.41e-05, 3.46e-06, 5.13e-06]    []
# 19000     [3.94e-05, 3.08e-06, 4.37e-06]    [1.28e-05, 3.08e-06, 4.37e-06]    []
# 20000     [2.65e-04, 1.60e-05, 6.15e-06]    [1.13e-04, 1.60e-05, 6.15e-06]    []
#
# Best model at step 19000:
#   train loss: 4.69e-05
#   test loss: 2.03e-05
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_20x3-20000.pt ...
#
# 'train' took 137.986859 s
#
# 0.24864018518510395
# 0.00850490974459621
# Compiling model...
# 'compile' took 0.000113 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [1.04e-02, 4.21e-02, 7.66e-01]    [9.24e-03, 4.21e-02, 7.66e-01]    []
# 1000      [1.09e-03, 2.02e-04, 6.08e-04]    [5.84e-04, 2.02e-04, 6.08e-04]    []
# 2000      [2.88e-04, 4.56e-05, 1.10e-04]    [1.49e-04, 4.56e-05, 1.10e-04]    []
# 3000      [1.36e-04, 1.98e-05, 5.19e-05]    [7.02e-05, 1.98e-05, 5.19e-05]    []
# 18000     [2.65e-04, 3.35e-06, 1.35e-05]    [5.97e-05, 3.35e-06, 1.35e-05]    []
# 19000     [9.79e-06, 6.88e-07, 4.73e-07]    [5.53e-06, 6.88e-07, 4.73e-07]    []
# 20000     [1.83e-05, 6.37e-07, 3.45e-06]    [9.71e-06, 6.37e-07, 3.45e-06]    []
#
# Best model at step 19000:
#   train loss: 1.10e-05
#   test loss: 6.69e-06
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_40x4-20000.pt ...
#
# 'train' took 367.704970 s
#
# 0.07929419575931893
# 0.0029598935223111855
# Compiling model...
# 'compile' took 0.000150 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [3.37e-02, 1.30e-02, 5.72e-01]    [3.42e-02, 1.30e-02, 5.72e-01]    []
# 1000      [1.53e-03, 4.79e-04, 6.74e-04]    [9.87e-04, 4.79e-04, 6.74e-04]    []
# 2000      [6.73e-04, 1.86e-04, 1.61e-04]    [4.08e-04, 1.86e-04, 1.61e-04]    []
# 3000      [7.28e-04, 1.53e-04, 1.61e-04]    [3.43e-04, 1.53e-04, 1.61e-04]    []
# 4000      [2.18e-04, 8.91e-05, 5.96e-05]    [1.31e-04, 8.91e-05, 5.96e-05]    []
# 5000      [1.40e-04, 6.75e-05, 3.97e-05]    [9.35e-05, 6.75e-05, 3.97e-05]    []
# 6000      [1.26e-04, 5.22e-05, 3.13e-05]    [7.17e-05, 5.22e-05, 3.13e-05]    []
# 7000      [5.23e-04, 4.04e-05, 8.04e-05]    [1.45e-04, 4.04e-05, 8.04e-05]    []
# 8000      [5.47e-04, 5.24e-05, 9.54e-05]    [2.00e-04, 5.24e-05, 9.54e-05]    []
# 9000      [6.99e-05, 2.88e-05, 1.21e-05]    [5.03e-05, 2.88e-05, 1.21e-05]    []
# 10000     [6.48e-05, 2.41e-05, 9.71e-06]    [4.57e-05, 2.41e-05, 9.71e-06]    []
# 11000     [2.37e-04, 2.63e-05, 3.31e-05]    [1.12e-04, 2.63e-05, 3.31e-05]    []
# 12000     [5.64e-05, 1.78e-05, 6.03e-06]    [4.04e-05, 1.78e-05, 6.03e-06]    []
# 13000     [4.60e-04, 1.48e-05, 5.57e-05]    [1.18e-04, 1.48e-05, 5.57e-05]    []
# 14000     [5.57e-05, 1.34e-05, 4.50e-06]    [3.50e-05, 1.34e-05, 4.50e-06]    []
# 15000     [5.23e-05, 1.18e-05, 4.15e-06]    [3.40e-05, 1.18e-05, 4.15e-06]    []
# 16000     [4.63e-05, 1.11e-05, 2.77e-06]    [3.32e-05, 1.11e-05, 2.77e-06]    []
# 17000     [4.50e-05, 9.88e-06, 2.57e-06]    [3.13e-05, 9.88e-06, 2.57e-06]    []
# 18000     [4.28e-05, 9.07e-06, 2.09e-06]    [3.07e-05, 9.07e-06, 2.09e-06]    []
# 19000     [4.12e-05, 8.24e-06, 1.82e-06]    [2.93e-05, 8.24e-06, 1.82e-06]    []
# 20000     [3.73e-04, 7.82e-06, 6.15e-05]    [9.95e-05, 7.82e-06, 6.15e-05]    []
#
# Best model at step 19000:
#   train loss: 5.13e-05
#   test loss: 3.93e-05
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_10x5-20000.pt ...
#
# 'train' took 128.426478 s
#
# 0.3555248293915365
# 0.01124256235152521
# Compiling model...
# 'compile' took 0.000103 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [1.70e-02, 2.32e-02, 4.62e-01]    [1.29e-02, 2.32e-02, 4.62e-01]    []
# 1000      [1.25e-03, 3.81e-04, 1.67e-04]    [6.21e-04, 3.81e-04, 1.67e-04]    []
# 2000      [5.26e-04, 7.39e-05, 3.02e-05]    [3.09e-04, 7.39e-05, 3.02e-05]    []
# 3000      [3.12e-04, 3.88e-05, 1.77e-05]    [1.88e-04, 3.88e-05, 1.77e-05]    []
# 4000      [3.06e-04, 4.65e-05, 4.92e-05]    [1.40e-04, 4.65e-05, 4.92e-05]    []
# 5000      [1.21e-04, 2.86e-05, 1.57e-05]    [6.29e-05, 2.86e-05, 1.57e-05]    []
# 6000      [7.00e-05, 2.31e-05, 9.78e-06]    [4.02e-05, 2.31e-05, 9.78e-06]    []
# 7000      [7.59e-05, 1.68e-05, 8.40e-06]    [3.69e-05, 1.68e-05, 8.40e-06]    []
# 8000      [5.42e-05, 1.32e-05, 7.35e-06]    [2.20e-05, 1.32e-05, 7.35e-06]    []
# 9000      [6.41e-05, 7.89e-06, 3.17e-06]    [1.99e-05, 7.89e-06, 3.17e-06]    []
# 10000     [6.08e-05, 6.49e-06, 2.95e-06]    [1.84e-05, 6.49e-06, 2.95e-06]    []
# 11000     [6.64e-05, 6.00e-06, 5.37e-06]    [1.87e-05, 6.00e-06, 5.37e-06]    []
# 12000     [7.24e-04, 1.08e-05, 6.67e-05]    [1.84e-04, 1.08e-05, 6.67e-05]    []
# 13000     [2.06e-04, 8.19e-06, 2.02e-05]    [5.80e-05, 8.19e-06, 2.02e-05]    []
# 14000     [2.56e-04, 7.55e-06, 2.25e-05]    [7.07e-05, 7.55e-06, 2.25e-05]    []
# 15000     [6.01e-05, 4.61e-06, 2.78e-06]    [1.51e-05, 4.61e-06, 2.78e-06]    []
# 16000     [4.89e-04, 5.24e-06, 5.66e-05]    [1.01e-04, 5.24e-06, 5.66e-05]    []
# 17000     [4.07e-04, 4.46e-06, 4.20e-05]    [8.13e-05, 4.46e-06, 4.20e-05]    []
# 18000     [4.60e-05, 5.77e-06, 4.79e-06]    [1.49e-05, 5.77e-06, 4.79e-06]    []
# 19000     [5.36e-05, 6.74e-06, 1.63e-05]    [1.73e-05, 6.74e-06, 1.63e-05]    []
# 20000     [3.14e-05, 4.02e-06, 6.02e-07]    [1.08e-05, 4.02e-06, 6.02e-07]    []
#
# Best model at step 20000:
#   train loss: 3.61e-05
#   test loss: 1.54e-05
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_20x5-20000.pt ...
#
# 'train' took 211.915170 s
#
# 0.1159040422465549
# 0.004449947255361044
# Compiling model...
# 'compile' took 0.000142 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [9.68e-02, 2.83e-02, 5.80e-01]    [1.02e-01, 2.83e-02, 5.80e-01]    []
# 1000      [4.66e-04, 3.42e-05, 7.42e-05]    [2.12e-04, 3.42e-05, 7.42e-05]    []
# 2000      [2.16e-04, 1.95e-05, 6.51e-05]    [1.27e-04, 1.95e-05, 6.51e-05]    []
# 3000      [1.41e-04, 1.15e-05, 1.90e-05]    [8.97e-05, 1.15e-05, 1.90e-05]    []
# 4000      [1.52e-04, 9.87e-06, 1.85e-05]    [7.94e-05, 9.87e-06, 1.85e-05]    []
# 5000      [5.99e-05, 5.29e-06, 4.63e-06]    [3.32e-05, 5.29e-06, 4.63e-06]    []
# 6000      [5.17e-04, 7.00e-06, 3.51e-05]    [1.35e-04, 7.00e-06, 3.51e-05]    []
# 7000      [1.20e-04, 8.35e-06, 1.10e-05]    [3.45e-05, 8.35e-06, 1.10e-05]    []
# 8000      [1.21e-04, 5.06e-06, 1.94e-06]    [3.68e-05, 5.06e-06, 1.94e-06]    []
# 9000      [2.52e-04, 6.98e-06, 2.36e-05]    [7.47e-05, 6.98e-06, 2.36e-05]    []
# 10000     [5.90e-05, 2.74e-06, 1.90e-06]    [1.69e-05, 2.74e-06, 1.90e-06]    []
# 11000     [3.90e-05, 2.36e-06, 3.48e-06]    [1.27e-05, 2.36e-06, 3.48e-06]    []
# 12000     [1.39e-04, 3.02e-06, 1.19e-05]    [3.63e-05, 3.02e-06, 1.19e-05]    []
# 13000     [9.32e-06, 2.06e-06, 1.27e-06]    [4.77e-06, 2.06e-06, 1.27e-06]    []
# 14000     [1.32e-04, 2.49e-06, 3.88e-06]    [3.14e-05, 2.49e-06, 3.88e-06]    []
# 15000     [3.46e-04, 2.39e-06, 4.86e-06]    [8.68e-05, 2.39e-06, 4.86e-06]    []
# 16000     [3.18e-05, 2.07e-06, 2.85e-06]    [8.51e-06, 2.07e-06, 2.85e-06]    []
# 17000     [1.74e-05, 1.93e-06, 2.78e-06]    [5.57e-06, 1.93e-06, 2.78e-06]    []
# 18000     [7.21e-05, 1.68e-06, 3.66e-06]    [1.82e-05, 1.68e-06, 3.66e-06]    []
# 19000     [6.06e-05, 2.30e-06, 4.51e-06]    [1.57e-05, 2.30e-06, 4.51e-06]    []
# 20000     [8.22e-04, 1.47e-05, 5.55e-05]    [2.22e-04, 1.47e-05, 5.55e-05]    []
#
# Best model at step 13000:
#   train loss: 1.27e-05
#   test loss: 8.10e-06
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_40x5-20000.pt ...
#
# 'train' took 470.335740 s
#
# 0.28006843748093946
# 0.01374884031928203
# Compiling model...
# 'compile' took 0.000111 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [8.21e-02, 4.91e-02, 2.79e-01]    [7.13e-02, 4.91e-02, 2.79e-01]    []
# 1000      [1.43e-03, 3.09e-04, 2.05e-04]    [7.30e-04, 3.09e-04, 2.05e-04]    []
# 2000      [7.84e-04, 1.82e-04, 9.72e-05]    [4.41e-04, 1.82e-04, 9.72e-05]    []
# 3000      [4.31e-04, 1.14e-04, 6.07e-05]    [2.54e-04, 1.14e-04, 6.07e-05]    []
# 4000      [4.10e-04, 7.64e-05, 6.02e-05]    [1.99e-04, 7.64e-05, 6.02e-05]    []
# 5000      [2.89e-04, 4.39e-05, 4.49e-05]    [1.40e-04, 4.39e-05, 4.49e-05]    []
# 6000      [2.04e-04, 2.31e-05, 2.21e-05]    [1.13e-04, 2.31e-05, 2.21e-05]    []
# 7000      [8.94e-04, 1.44e-05, 1.42e-04]    [2.38e-04, 1.44e-05, 1.42e-04]    []
# 8000      [1.41e-04, 9.08e-06, 1.73e-05]    [5.73e-05, 9.08e-06, 1.73e-05]    []
# 13000     [3.37e-05, 4.07e-06, 2.23e-06]    [1.21e-05, 4.07e-06, 2.23e-06]    []
# 14000     [2.37e-05, 3.01e-06, 1.89e-06]    [9.18e-06, 3.01e-06, 1.89e-06]    []
# 15000     [4.23e-05, 2.94e-06, 2.54e-06]    [1.31e-05, 2.94e-06, 2.54e-06]    []
# 16000     [9.16e-06, 2.40e-06, 1.63e-06]    [4.39e-06, 2.40e-06, 1.63e-06]    []
# 17000     [5.87e-04, 5.17e-06, 8.28e-06]    [1.30e-04, 5.17e-06, 8.28e-06]    []
# 18000     [3.89e-05, 3.00e-06, 2.24e-06]    [1.16e-05, 3.00e-06, 2.24e-06]    []
# 19000     [2.30e-05, 2.10e-06, 2.05e-06]    [7.41e-06, 2.10e-06, 2.05e-06]    []
# 20000     [3.35e-05, 2.54e-06, 2.06e-06]    [1.01e-05, 2.54e-06, 2.06e-06]    []
#
# Best model at step 16000:
#   train loss: 1.32e-05
#   test loss: 8.42e-06
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_20x6-20000.pt ...
#
# 'train' took 249.283611 s
#
# 0.10955412570481238
# 0.006584849794974596
# Compiling model...
# 'compile' took 0.000114 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [7.60e-02, 3.61e-02, 3.79e-01]    [7.69e-02, 3.61e-02, 3.79e-01]    []
# 1000      [1.71e-02, 6.52e-04, 6.11e-04]    [6.00e-03, 6.52e-04, 6.11e-04]    []
# 2000      [1.48e-04, 3.77e-05, 4.54e-05]    [6.43e-05, 3.77e-05, 4.54e-05]    []
# 3000      [1.46e-03, 8.78e-05, 6.94e-05]    [4.75e-04, 8.78e-05, 6.94e-05]    []
# 4000      [4.22e-04, 2.53e-05, 2.22e-05]    [1.22e-04, 2.53e-05, 2.22e-05]    []
# 5000      [6.62e-04, 3.74e-05, 4.77e-06]    [1.30e-04, 3.74e-05, 4.77e-06]    []
# 6000      [2.71e-04, 2.56e-05, 1.77e-05]    [7.88e-05, 2.56e-05, 1.77e-05]    []
# 7000      [3.70e-04, 2.18e-05, 1.39e-05]    [9.91e-05, 2.18e-05, 1.39e-05]    []
# 8000      [1.75e-05, 6.09e-06, 1.80e-06]    [1.03e-05, 6.09e-06, 1.80e-06]    []
# 9000      [6.14e-04, 2.05e-05, 1.63e-05]    [1.47e-04, 2.05e-05, 1.63e-05]    []
# 10000     [2.90e-05, 3.69e-06, 3.43e-06]    [1.43e-05, 3.69e-06, 3.43e-06]    []
# 11000     [3.11e-05, 3.21e-06, 3.99e-06]    [1.17e-05, 3.21e-06, 3.99e-06]    []
# 12000     [6.13e-05, 2.44e-06, 2.54e-06]    [1.95e-05, 2.44e-06, 2.54e-06]    []
# 13000     [3.69e-04, 5.45e-06, 4.16e-06]    [7.71e-05, 5.45e-06, 4.16e-06]    []
# 14000     [4.08e-05, 2.34e-06, 8.19e-07]    [1.13e-05, 2.34e-06, 8.19e-07]    []
# 15000     [7.50e-05, 2.68e-06, 5.66e-06]    [2.50e-05, 2.68e-06, 5.66e-06]    []
# 16000     [7.84e-04, 2.17e-06, 2.25e-05]    [1.48e-04, 2.17e-06, 2.25e-05]    []
# 17000     [3.76e-05, 4.16e-06, 1.90e-06]    [1.10e-05, 4.16e-06, 1.90e-06]    []
# 18000     [3.82e-04, 1.28e-05, 5.88e-05]    [1.12e-04, 1.28e-05, 5.88e-05]    []
# 19000     [2.43e-05, 1.90e-06, 1.10e-06]    [8.82e-06, 1.90e-06, 1.10e-06]    []
# 20000     [3.35e-04, 1.11e-05, 1.82e-05]    [6.96e-05, 1.11e-05, 1.82e-05]    []
#
# Best model at step 8000:
#   train loss: 2.54e-05
#   test loss: 1.82e-05
#   test metric: []
#
# Epoch 20000: saving model to ../modelos/heat_40x6-20000.pt ...
#
# 'train' took 571.523130 s
#
# 0.22197302240993994
# 0.011305458572068628

# %%
norm_df = pd.DataFrame(table, columns=['Nº Camadas Escondidas', 'Nº Nós', 'Norm. Infinito'])

# %%
norm_df
# Out:
#     Nº Camadas Escondidas  Nº Nós  Norm. Infinito
# 0                       1      10        0.162978
# 1                       1      20        0.067027
# 2                       1      40        0.029668
# 3                       2      10        0.014183
# 4                       2      20        0.003422
# 5                       2      40        0.015043
# 6                       3      10        0.003373
# 7                       3      20        0.002797
# 8                       3      40        0.003647
# 9                       4      10        0.005014
# 10                      4      20        0.008900
# 11                      4      40        0.004752
# 12                      5      10        0.017533
# 13                      5      20        0.006346
# 14                      5      40        0.003624
# 15                      6      10        0.004662
# 16                      6      20        0.004071
# 17                      6      40        0.007644

# %%
norm_df[norm_df["Norm. Infinito"]==norm_df["Norm. Infinito"].min()]
# Out:
#    Nº Camadas Escondidas  Nº Nós  Norm. Infinito
# 7                      3      20        0.002797

# %% [markdown]
# ## Visualizando Resultados

# %%
best_n_hidden_l = 3
best_n_nodes = 20

# %%
best_net = dde.nn.FNN([2] + [best_n_nodes] * best_n_hidden_l + [1], "tanh", "Glorot normal")
best_model = dde.Model(data, best_net)
best_model.compile("adam", lr=0.001)
# Out:
# Compiling model...
# 'compile' took 0.000403 s

# %%
best_model.train(iterations=20000)
# Out:
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [2.67e-01, 8.74e-02, 9.46e-01]    [2.69e-01, 8.74e-02, 9.46e-01]    []
# 1000      [5.09e-03, 2.47e-03, 1.04e-02]    [2.20e-03, 2.47e-03, 1.04e-02]    []
# 2000      [9.05e-04, 8.59e-05, 2.43e-04]    [5.17e-04, 8.59e-05, 2.43e-04]    []
# 3000      [4.24e-04, 3.71e-05, 8.77e-05]    [2.62e-04, 3.71e-05, 8.77e-05]    []
# 4000      [1.85e-03, 4.32e-05, 2.48e-04]    [6.68e-04, 4.32e-05, 2.48e-04]    []
# 5000      [1.78e-04, 1.70e-05, 2.74e-05]    [1.13e-04, 1.70e-05, 2.74e-05]    []
# 6000      [1.27e-04, 1.23e-05, 1.70e-05]    [7.94e-05, 1.23e-05, 1.70e-05]    []
# 7000      [1.08e-04, 1.16e-05, 1.82e-05]    [5.92e-05, 1.16e-05, 1.82e-05]    []
# 8000      [7.43e-05, 7.24e-06, 8.31e-06]    [4.38e-05, 7.24e-06, 8.31e-06]    []
# 9000      [6.13e-05, 5.33e-06, 5.56e-06]    [3.57e-05, 5.33e-06, 5.56e-06]    []
# 10000     [5.17e-05, 4.04e-06, 3.97e-06]    [2.97e-05, 4.04e-06, 3.97e-06]    []
# 11000     [4.53e-05, 4.09e-06, 4.80e-06]    [2.50e-05, 4.09e-06, 4.80e-06]    []
# 12000     [3.80e-05, 3.16e-06, 3.38e-06]    [2.13e-05, 3.16e-06, 3.38e-06]    []
# 13000     [3.29e-05, 2.36e-06, 2.28e-06]    [1.88e-05, 2.36e-06, 2.28e-06]    []
# 14000     [2.89e-05, 1.93e-06, 1.79e-06]    [1.67e-05, 1.93e-06, 1.79e-06]    []
# 15000     [2.56e-05, 1.59e-06, 1.43e-06]    [1.49e-05, 1.59e-06, 1.43e-06]    []
# 16000     [2.26e-05, 1.32e-06, 1.18e-06]    [1.33e-05, 1.32e-06, 1.18e-06]    []
# 17000     [1.99e-05, 1.35e-06, 1.45e-06]    [1.20e-05, 1.35e-06, 1.45e-06]    []
# 18000     [1.80e-05, 1.01e-06, 9.01e-07]    [1.09e-05, 1.01e-06, 9.01e-07]    []
# 19000     [2.39e-04, 6.27e-06, 2.31e-05]    [8.46e-05, 6.27e-06, 2.31e-05]    []
# 20000     [1.47e-05, 7.92e-07, 7.28e-07]    [9.16e-06, 7.92e-07, 7.28e-07]    []
#
# Best model at step 20000:
#   train loss: 1.62e-05
#   test loss: 1.07e-05
#   test metric: []
#
# 'train' took 133.905461 s
# (<deepxde.model.LossHistory at 0x7fe498e46c00>,
#  <deepxde.model.TrainState at 0x7fe498e45c70>)

# %%
nop = 25
X, Y, XY = create_test_points(nop)

Z_best_model = best_model.predict(XY)
Z_exact_sol = exact_solution(XY)

Z_best_model = Z_best_model.reshape((nop, nop))
Z_exact_sol = Z_exact_sol.reshape((nop, nop))

# %%
def plot_3d_and_save(X, Y, Z, file_path):
 
    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
    ax.plot_surface(Y, X, Z, vmin=Z.min() * 2, cmap="viridis")
    
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.savefig(file_path)
    plt.show()

# %%
plot_3d_and_save(X, Y, Z_best_model, "../figuras/heat_pinns.pdf")

# %%
plot_3d_and_save(X, Y, Z_exact_sol, "../figuras/heat_exato.pdf")

# %% [markdown]
# ## Analisando função de perda

# %%
def plot_and_save_losses(losshistory, file_path):
    
    X = losshistory.steps
    train = np.sum(losshistory.loss_train, axis=1)
    test = np.sum(losshistory.loss_test, axis=1)
    
    plt.semilogy(X, train, "o-", label="Treinamento", linewidth=2)
    plt.semilogy(X, test, "x-", label="Teste", linewidth=2)

    plt.xlabel("Iteração")
    plt.ylabel("Erro em escala logarítmica")
    
    plt.legend()
    plt.grid()
    plt.savefig(file_path)
    plt.show()

# %%
plot_and_save_losses(best_model.losshistory, "../figuras/heat_loss.pdf")

# %% [markdown]
# ## Métricas

# %%
np.sqrt(dde.metrics.mean_squared_error(Z_exact_sol, Z_best_model))
# Out:
# np.float64(0.0006253221772146983)

# %%
scipy.linalg.norm(Z_exact_sol - Z_best_model, ord=2)
# Out:
# np.float64(0.013073955672521894)

# %%
scipy.linalg.norm(Z_exact_sol - Z_best_model, ord=np.inf)
# Out:
# 0.019938036997561238
